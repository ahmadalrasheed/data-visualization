# %% [markdown]
# ## Lab: 14 - Data Visualization
# Today , I will be telling you a nice story about something which is very harmful and every body must take care from it and stay a way from it , because its very dangerous and it affected my life a lot in a very negative way , but finally i Got rid of it , Which is smoking.

# %% [markdown]
# I was a smoker for a very long time actually more than 7 Years , and i quitted smoking before 1 month and after i did that actually my life totally changed , the stress is gone , my breathing is far more better , my mood , everything  in my life starts to be amazing.

# %% [markdown]
# i will explain to you right now with real data what is smoking impact on your health in a very smooth way so you can be a ware from it.

# %% [markdown]
# First of all we have to study the number of people who are smoking from the previous years and how their numbers are changing so that we can have a clear vision about this problem.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv('tobacco.csv')
df
# Out:
#      Year                       State Smoke everyday Smoke some days  \
# 0    1996                 Puerto Rico          9.40%           5.10%
# 1    1997                 Puerto Rico          9.40%              5%
# 2    1998                 Puerto Rico         10.10%           5.20%
# 3    1999                 Puerto Rico          9.70%              4%
# 4    2000                 Puerto Rico          9.20%           3.90%
# ..    ...                         ...            ...             ...
# 871  1995  Nationwide (States and DC)         19.90%           2.60%
# 872  2010                        Guam         19.70%           6.10%
# 873  2009                        Guam         18.90%           5.20%
# 874  2010              Virgin Islands          3.60%           2.20%
# 875  2009              Virgin Islands          3.90%           2.60%
#
#     Former smoker Never smoked           Location 1
# 0             16%       69.50%        Puerto Rico\n
# ...

# %%
#the first 23 coloums which represent time of 23 years for one location
new_df=df.head(23)
new_df
# Out:
#     Year           State Smoke everyday Smoke some days Former smoker  \
# 0   1996     Puerto Rico          9.40%           5.10%           16%
# 1   1997     Puerto Rico          9.40%              5%        15.70%
# 2   1998     Puerto Rico         10.10%           5.20%        16.80%
# 3   1999     Puerto Rico          9.70%              4%        15.30%
# 4   2000     Puerto Rico          9.20%           3.90%        15.20%
# 5   2001     Puerto Rico             8%           4.50%           17%
# 6   2001  Virgin Islands          6.90%           2.70%        12.60%
# 7   2002     Puerto Rico          8.80%           4.40%        16.90%
# 8   2002  Virgin Islands             7%           2.40%        12.10%
# 9   2003     Puerto Rico          8.90%           4.60%        17.70%
# 10  2003  Virgin Islands          7.90%              2%        13.60%
# 11  2004     Puerto Rico          8.20%           4.40%        15.20%
# ...

# %%
# draw the relation between years and smoking percentage
plt.scatter(new_df['Year'],new_df['Smoke everyday'],color='red')
plt.xlabel('Years')
plt.ylabel('percentage of smokers')
plt.title('Smoking percentages in 23years')
# Out:
# Text(0.5, 1.0, 'Smoking percentages in 23years')

# %%
sns.set()

smokers_df=new_df[['Year','Smoke everyday']]
smokers_df
sns.relplot(x="Year",y="Smoke everyday",data=new_df)

# %% [markdown]
# So this is good indication actually , we recogbnized that during 23 years in one location smoking percentage for people who smokes evry day are getting down on down and this is perfect !

# %% [markdown]
# Let's see the relation between years and non-smokers percentage.

# %%
# draw the relation between years and nonsmokers percentage
sns.relplot(x="Year",y="Never smoked",  data=new_df,color='green')

plt.xlabel('Years')
plt.ylabel('percentage of Non-smokers')
plt.title('Non-Smoking percentages in 23years')
# Out:
# Text(0.5, 1.0, 'Non-Smoking percentages in 23years')

# %% [markdown]
# ## Conclusion
# * Smoker number is decreasing year by year
# * non smoker numbers is greater that means people is starting to know the negative impact of smoking
